# %%
import pandas as pd, matplotlib.pyplot as plt, seaborn as sns, re

# %%
df = pd.read_excel('Goodreads_Books_Dataset.xlsx', sheet_name='Dataset')
df.sample(10)
# Out:
#       bookID                                              title  \
# 9982   40209  Maggie: A Girl of the Streets and Other Tales ...
# 4755   17075   Lost World of Agharti: The Mystery of Vril Power
# 1550    5351                                  The Street Lawyer
# 7868   30262  The Good  the Bad  and the Undead (The Hollows...
# 757     2494                                   The Time Machine
# 178      414                                           Vineland
# 5650   20957  Colossians and Philemon: A Critical and Exeget...
# 6800   25553                                The Best Bug Parade
# 1660    5797                                        Vanity Fair
# 5630   20867       Line of Control (Tom Clancy's Op-Center  #8)
#
#                                                 authors average_rating  \
# 9982               Stephen Crane/Larzer Ziff/Theo Davis           3.66
# 4755                                     Alec MacLellan           3.84
# ...

# %%
df['  num_pages'].unique()
# Out:
# array([652, 870, 352, 435, 2690, 152, 3342, 815, 215, 6, 544, 55, 256,
#        335, 304, 299, 254, 324, 270, 1728, 1184, 398, 1216, 218, 224, 558,
#        208, 48, 144, 56, 228, 137, 339, 369, 388, 14, 576, 334, 416, 248,
#        128, 288, 720, 448, 160, 81, 249, 138, 192, 108, 832, 123, 423,
#        436, 331, 592, 480, 426, 471, 291, 205, 240, 336, 386, 260, 384,
#        391, 864, 873, 206, 514, 838, 960, 837, 80, 803, 752, 360, 367,
#        320, 100, 216, 250, 32, 244, 191, 738, 287, 217, 154, 318, 348,
#        316, 506, 292, 797, 635, 91, 181, 178, 464, 102, 132, 311, 213,
#        245, 64, 272, 232, 147, 239, 528, 434, 439, 307, 298, 368, 72, 67,
#        347, 317, 827, 377, 1085, 547, 784, 773, 385, 776, 193, 227, 222,
#        238, 234, 1122, 231, 308, 203, 96, 179, 306, 145, 275, 104, 1075,
#        608, 211, 262, 88, 542, 828, 112, 397, 328, 532, 296, 456, 575,
#        419, 540, 408, 1392, 1168, 176, 105, 340, 681, 286, 571, 277, 826,
# ...

# %%
df['num_pages'] = df['  num_pages'].str.replace('eng','')
df['num_pages'] = df['  num_pages'].str.replace('en-US','')

# %%
df.num_pages.unique()
# Out:
# array([nan, '', 'eng'], dtype=object)

# %%
df.index('eng')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SAHEED~1\AppData\Local\Temp/ipykernel_18752/558459571.py in <module>
# ----> 1 df.index('eng')
#
# TypeError: 'RangeIndex' object is not callable

# %%
df.info()

# %%
df.rename({'  num_pages' : 'num_pages'}, inplace=True)

# %%
df['  num_pages'].astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SAHEED~1\AppData\Local\Temp/ipykernel_18752/1764438151.py in <module>
# ----> 1 df['  num_pages'].astype('int')
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...
