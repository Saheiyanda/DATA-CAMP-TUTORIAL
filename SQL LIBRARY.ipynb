# %%
import pandas as pd
from pandasql import sqldf

# %%
df = pd.read_csv('bikes_sharing.csv')

# %%
df.columns
# Out:
# Index(['hr', 'holiday', 'workingday', 'temp', 'hum', 'windspeed', 'cnt',
#        'instant', 'mnth', 'yr', 'Clear to partly cloudy',
#        'Light Precipitation', 'Misty'],
#       dtype='object')

# %%
df.head()
# Out:
#    hr  holiday  workingday  temp   hum  windspeed  cnt  instant  mnth  yr  \
# 0   0        0           0  0.76  0.66     0.0000  149    13004     7   1
# 1   1        0           0  0.74  0.70     0.1343   93    13005     7   1
# 2   2        0           0  0.72  0.74     0.0896   90    13006     7   1
# 3   3        0           0  0.72  0.84     0.1343   33    13007     7   1
# 4   4        0           0  0.70  0.79     0.1940    4    13008     7   1
#
#    Clear to partly cloudy  Light Precipitation  Misty
# 0                       1                    0      0
# 1                       1                    0      0
# 2                       1                    0      0
# 3                       1                    0      0
# 4                       1                    0      0

# %%
# select all months for df
df_sql ="""select temp
from df"""
sqldf(df_sql)
# Out:
#       temp
# 0     0.76
# 1     0.74
# 2     0.72
# 3     0.72
# 4     0.70
# ...    ...
# 1483  0.80
# 1484  0.80
# 1485  0.76
# 1486  0.76
# 1487  0.74
#
# [1488 rows x 1 columns]

# %%
# Select all fields from the books table
df_sql = """
select *
from df"""

# %%
sqldf(df_sql)
# Out:
#       hr  holiday  workingday  temp   hum  windspeed  cnt  instant  mnth  yr  \
# 0      0        0           0  0.76  0.66     0.0000  149    13004     7   1
# 1      1        0           0  0.74  0.70     0.1343   93    13005     7   1
# 2      2        0           0  0.72  0.74     0.0896   90    13006     7   1
# 3      3        0           0  0.72  0.84     0.1343   33    13007     7   1
# 4      4        0           0  0.70  0.79     0.1940    4    13008     7   1
# ...   ..      ...         ...   ...   ...        ...  ...      ...   ...  ..
# 1483  19        0           1  0.80  0.49     0.1343  452    14487     8   1
# 1484  20        0           1  0.80  0.49     0.1343  356    14488     8   1
# 1485  21        0           1  0.76  0.58     0.1940  303    14489     8   1
# 1486  22        0           1  0.76  0.58     0.1940  277    14490     8   1
# 1487  23        0           1  0.74  0.62     0.1045  174    14491     8   1
#
#       Clear to partly cloudy  Light Precipitation  Misty
# 0                          1                    0      0
# 1                          1                    0      0
# 2                          1                    0      0
# 3                          1                    0      0
# 4                          1                    0      0
# ...                      ...                  ...    ...
# 1483                       1                    0      0
# 1484                       1                    0      0
# 1485                       1                    0      0
# 1486                       1                    0      0
# 1487                       1                    0      0
#
# [1488 rows x 13 columns]

# %%
# Select unique country from the books table
df_cntry = pd.read_csv('countries.csv')

# Select distinct(author)
df_cntry_1 = """
select distinct(country_name)
from df_cntry"""

# %%
df_cntry.columns
# Out:
# Index(['code', 'country_name', 'continent', 'region', 'surface_area',
#        'indep_year', 'local_name', 'gov_form', 'capital', 'cap_long',
#        'cap_lat'],
#       dtype='object')

# %%
sqldf(df_cntry_1)
# Out:
#              country_name
# 0             Afghanistan
# 1             Netherlands
# 2                 Albania
# 3                 Algeria
# 4          American Samoa
# ..                    ...
# 200               Estonia
# 201         United States
# 202  Virgin Islands, U.S.
# 203              Zimbabwe
# 204             Palestine
#
# [205 rows x 1 columns]

# %%
# Select unique authors and genre combinations from the books tabledf
df_cntry_2 ="""

select distinct(country_name),continent
from df_cntry"""

# %%
sqldf(df_cntry_2)
# Out:
#              country_name      continent
# 0             Afghanistan           Asia
# 1             Netherlands         Europe
# 2                 Albania         Europe
# 3                 Algeria         Africa
# 4          American Samoa        Oceania
# ..                    ...            ...
# 200               Estonia         Europe
# 201         United States  North America
# 202  Virgin Islands, U.S.  North America
# 203              Zimbabwe         Africa
# 204             Palestine           Asia
#
# [205 rows x 2 columns]

# %% [markdown]
# Amazing! As your SQL queries become long and complex, you'll want to be able to save your queries for referencing later. Views can also be useful when the information contained in a database table isn't quite what you need. You can create your own custom view with exactly the information you are looking for, without needing to edit the database itself, which you may not have permission to do. Creating views is a valuable skill to have, and you've mastered it!

# %%
# Your code to create the view:
# -- Your code to create the view:
# CREATE VIEW library_authors AS
# SELECT DISTINCT author AS unique_author
# FROM books;

# -- Select all columns from library_authors
# Select *
# from library_authors

df_cntry_3 = """
CREATE VIEW library_authors AS
SELECT DISTINCT country_name AS unique_country
FROM df_cntry"""

# %%
sqldf(df_cntry_3)

# %%
df_cntry_4 = """
select *
from library_authors"""

# %%
# Select the first 10 genres from books using PostgreSQL
df_cntry_6 = """
Select country_name
from df_cntry
limit 10"""

# %%
sqldf(df_cntry_6)
# Out:
#            country_name
# 0           Afghanistan
# 1           Netherlands
# 2               Albania
# 3               Algeria
# 4        American Samoa
# 5               Andorra
# 6                Angola
# 7   Antigua and Barbuda
# 8  United Arab Emirates
# 9             Argentina
