# %%
# <a class="dc-link ds-snowplow-link-course-dataset" target="_blank" rel="noopener noreferrer" href="https://assets.datacamp.com/production/repositories/5975/datasets/17ec88d6bf920ba7f159298d6acba118a907dacf/coffee_ratings_full.feather">
#             Coffee ratings
# </a>

# %%
# !pip install -q pyarrow

# %%
import pandas as pd
data1 = pd.read_feather("coffee_ratings_full.feather")
data1.head()
# Out:
#    total_cup_points  species                     owner country_of_origin  \
# 0             90.58  Arabica                 metad plc          Ethiopia
# 1             89.92  Arabica                 metad plc          Ethiopia
# 2             89.75  Arabica  grounds for health admin         Guatemala
# 3             89.00  Arabica       yidnekachew dabessa          Ethiopia
# 4             88.83  Arabica                 metad plc          Ethiopia
#
#                                   farm_name lot_number       mill ico_number  \
# 0                                 metad plc       None  metad plc  2014/2015
# 1                                 metad plc       None  metad plc  2014/2015
# 2  san marcos barrancas "san cristobal cuch       None       None       None
# 3     yidnekachew dabessa coffee plantation       None    wolensu       None
# 4                                 metad plc       None  metad plc  2014/2015
#
# ...

# %%
import pandas as pd
data2 = pd.read_feather("spotify_2000_2020.feather")
data2.head()
# Out:
#    acousticness          artists  danceability  duration_ms  duration_minutes  \
# 0       0.97200  ['David Bauer']         0.567     313293.0          5.221550
# 1       0.32100   ['Etta James']         0.821     360240.0          6.004000
# 2       0.00659    ['Quasimoto']         0.706     202507.0          3.375117
# 3       0.00390  ['Millencolin']         0.368     173360.0          2.889333
# 4       0.12200   ['Steve Chou']         0.501     344200.0          5.736667
#
#    energy  explicit                      id  instrumentalness   key  liveness  \
# 0   0.227       0.0  0w0D8H1ubRerCXHWYJkinO          0.601000  10.0     0.110
# 1   0.418       0.0  4JVeqfE2tpi7Pv63LJZtPh          0.000372   9.0     0.222
# 2   0.602       1.0  5pxtdhLAi0RTh1gNqhGMNA          0.000138  11.0     0.400
# 3   0.977       0.0  3jRsoe4Vkxa4BMYqGHX8L0          0.000000  11.0     0.350
# 4   0.511       0.0  4mronxcllhfyhBRqyZi8kU          0.000000   7.0     0.279
#
# ...

# %%
import pandas as pd
data3 = pd.read_feather("attrition.feather")
data3.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate            Department  \
# 0   21        0.0      Travel_Rarely        391  Research_Development
# 1   19        1.0      Travel_Rarely        528                 Sales
# 2   18        1.0      Travel_Rarely        230  Research_Development
# 3   18        0.0      Travel_Rarely        812                 Sales
# 4   18        1.0  Travel_Frequently       1306                 Sales
#
#    DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 0                15        College  Life_Sciences                    High
# 1                22  Below_College      Marketing               Very_High
# 2                 3       Bachelor  Life_Sciences                    High
# 3                10       Bachelor        Medical               Very_High
# 4                 5       Bachelor      Marketing                  Medium
#
#    Gender  ...  PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
data3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 31 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int32
#  1   Attrition                 1470 non-null   float64
#  2   BusinessTravel            1470 non-null   category
#  3   DailyRate                 1470 non-null   int32
#  4   Department                1470 non-null   category
#  5   DistanceFromHome          1470 non-null   int32
#  6   Education                 1470 non-null   category
#  7   EducationField            1470 non-null   category
#  8   EnvironmentSatisfaction   1470 non-null   category
#  9   Gender                    1470 non-null   category
#  10  HourlyRate                1470 non-null   int32
#  11  JobInvolvement            1470 non-null   category
#  12  JobLevel                  1470 non-null   int32
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

k=data3['RelationshipSatisfaction'].value_counts()

# %%
k
# Out:
# High         459
# Very_High    432
# Medium       303
# Low          276
# Name: RelationshipSatisfaction, dtype: int64

# %%
sns.countplot(y = k, data=data3)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
# select all rows with a condition

# %%
df_con = data3['RelationshipSatisfaction']=='High'

# %%
data3.loc[df_con]
# Out:
#       Age  Attrition     BusinessTravel  DailyRate            Department  \
# 2      18        1.0      Travel_Rarely        230  Research_Development
# 5      27        0.0         Non-Travel        443  Research_Development
# 8      18        0.0         Non-Travel       1124  Research_Development
# 9      18        1.0  Travel_Frequently        544                 Sales
# 10     18        0.0         Non-Travel       1431  Research_Development
# ...   ...        ...                ...        ...                   ...
# 1444   53        0.0      Travel_Rarely        102  Research_Development
# 1461   55        0.0      Travel_Rarely        685                 Sales
# 1462   54        0.0      Travel_Rarely        584  Research_Development
# 1464   55        0.0      Travel_Rarely        452  Research_Development
# 1467   58        0.0      Travel_Rarely        682                 Sales
#
#       DistanceFromHome Education EducationField EnvironmentSatisfaction  \
# ...

# %%
data3['EducationField'].value_counts()
# Out:
# Life_Sciences       606
# Medical             464
# Marketing           159
# Technical_Degree    132
# Other                82
# Human_Resources      27
# Name: EducationField, dtype: int64

# %%
data3['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        1043
# Travel_Frequently     277
# Non-Travel            150
# Name: BusinessTravel, dtype: int64

# %%
A = data3['BusinessTravel']=='Travel_Rarely '

# %%
B = data3['EducationField']== 'Life_Sciences'

# %%
data3.loc[(A) | (B)]
# Out:
#       Age  Attrition BusinessTravel  DailyRate            Department  \
# 0      21        0.0  Travel_Rarely        391  Research_Development
# 2      18        1.0  Travel_Rarely        230  Research_Development
# 6      18        0.0     Non-Travel        287  Research_Development
# 8      18        0.0     Non-Travel       1124  Research_Development
# 11     30        0.0  Travel_Rarely       1358  Research_Development
# ...   ...        ...            ...        ...                   ...
# 1459   54        0.0  Travel_Rarely        685  Research_Development
# 1460   56        0.0  Travel_Rarely        206       Human_Resources
# 1463   56        0.0  Travel_Rarely       1400  Research_Development
# 1465   55        0.0  Travel_Rarely       1117                 Sales
# 1469   58        1.0  Travel_Rarely        286  Research_Development
#
#       DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# ...

# %%
# select with multiple conditions
#  dist_home = data3['DistanceFromHome']>15
# educ_coll = data3['Education']=='College'

# %%
# print(data3.loc[(dist_home) & (educ_coll)])

# %%
# print(data3.loc[(dist_home) | (educ_coll)])

# %%
#Select a range of rows using loc
data3.loc[1:3]
# Out:
#    Age  Attrition BusinessTravel  DailyRate            Department  \
# 1   19        1.0  Travel_Rarely        528                 Sales
# 2   18        1.0  Travel_Rarely        230  Research_Development
# 3   18        0.0  Travel_Rarely        812                 Sales
#
#    DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 1                22  Below_College      Marketing               Very_High
# 2                 3       Bachelor  Life_Sciences                    High
# 3                10       Bachelor        Medical               Very_High
#
#    Gender  ...  PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# 1    Male  ...          Excellent                Very_High                 0
# 2    Male  ...          Excellent                     High                 0
# 3  Female  ...          Excellent                      Low                 0
#
#   TotalWorkingYears TrainingTimesLastYear WorkLifeBalance  YearsAtCompany  \
# ...

# %%
# select few columns with a condition
data3.loc[(data3.Education=='Bachelor'),['Department','DistanceFromHome']].head()
# Out:
#              Department  DistanceFromHome
# 2  Research_Development                 3
# 3                 Sales                10
# 4                 Sales                 5
# 5  Research_Development                 3
# 8  Research_Development                 1

# %%
# update a column with condition
data3.head(20)
# Out:
#     Age  Attrition     BusinessTravel  DailyRate            Department  \
# 0    21        0.0      Travel_Rarely        391  Research_Development
# 1    19        1.0      Travel_Rarely        528                 Sales
# 2    18        1.0      Travel_Rarely        230  Research_Development
# 3    18        0.0      Travel_Rarely        812                 Sales
# 4    18        1.0  Travel_Frequently       1306                 Sales
# 5    27        0.0         Non-Travel        443  Research_Development
# 6    18        0.0         Non-Travel        287  Research_Development
# 7    18        1.0         Non-Travel        247  Research_Development
# 8    18        0.0         Non-Travel       1124  Research_Development
# 9    18        1.0  Travel_Frequently        544                 Sales
# 10   18        0.0         Non-Travel       1431  Research_Development
# 11   30        0.0      Travel_Rarely       1358  Research_Development
# ...

# %%
data3.loc[data3.Age>=18,'Attrition']=1

# %%
data3.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate            Department  \
# 0   21        1.0      Travel_Rarely        391  Research_Development
# 1   19        1.0      Travel_Rarely        528                 Sales
# 2   18        1.0      Travel_Rarely        230  Research_Development
# 3   18        1.0      Travel_Rarely        812                 Sales
# 4   18        1.0  Travel_Frequently       1306                 Sales
#
#    DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# 0                15        College  Life_Sciences                    High
# 1                22  Below_College      Marketing               Very_High
# 2                 3       Bachelor  Life_Sciences                    High
# 3                10       Bachelor        Medical               Very_High
# 4                 5       Bachelor      Marketing                  Medium
#
#    Gender  ...  PerformanceRating RelationshipSatisfaction  StockOptionLevel  \
# ...

# %%
data3.loc[data3.Age>=18,'Attrition']=data3.Attrition * data3.DailyRate

# %%
data3
# Out:
#       Age  Attrition     BusinessTravel  DailyRate            Department  \
# 0      21      391.0      Travel_Rarely        391  Research_Development
# 1      19      528.0      Travel_Rarely        528                 Sales
# 2      18      230.0      Travel_Rarely        230  Research_Development
# 3      18      812.0      Travel_Rarely        812                 Sales
# 4      18     1306.0  Travel_Frequently       1306                 Sales
# ...   ...        ...                ...        ...                   ...
# 1465   55     1117.0      Travel_Rarely       1117                 Sales
# 1466   58      350.0         Non-Travel        350                 Sales
# 1467   58      682.0      Travel_Rarely        682                 Sales
# 1468   58      147.0      Travel_Rarely        147  Research_Development
# 1469   58      286.0      Travel_Rarely        286  Research_Development
#
#       DistanceFromHome      Education EducationField EnvironmentSatisfaction  \
# ...

# %%
# update multiple columns with condition
data3.loc[(data3.Age>=18),['Attrition','DailyRate']]=['K','M'] # This code does not apply to categorical column.

# %%
data3
# Out:
#       Age Attrition     BusinessTravel DailyRate            Department  \
# 0      21         K      Travel_Rarely         M  Research_Development
# 1      19         K      Travel_Rarely         M                 Sales
# 2      18         K      Travel_Rarely         M  Research_Development
# 3      18         K      Travel_Rarely         M                 Sales
# 4      18         K  Travel_Frequently         M                 Sales
# ...   ...       ...                ...       ...                   ...
# 1465   55         K      Travel_Rarely         M                 Sales
# 1466   58         K         Non-Travel         M                 Sales
# 1467   58         K      Travel_Rarely         M                 Sales
# 1468   58         K      Travel_Rarely         M  Research_Development
# 1469   58         K      Travel_Rarely         M  Research_Development
#
#       DistanceFromHome Education EducationField EnvironmentSatisfaction  \
# ...

# %%
# select rows with indexes
data3.iloc[(1,3)]
# Out:
# 'M'

# %%
# select rows with particular indexes and particular columns
data3.iloc[[1,3],[1,4]]
# Out:
#   Attrition Department
# 1         K      Sales
# 3         K      Sales

# %%
# select a range of rows
data3.iloc[1:3,1:4]
# Out:
#   Attrition BusinessTravel DailyRate
# 1         K  Travel_Rarely         M
# 2         K  Travel_Rarely         M

# %%
data3.iloc[(1,3)]
# Out:
# 'M'
